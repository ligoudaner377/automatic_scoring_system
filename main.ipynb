# %%
from scorer import Scorer
scorer = Scorer()
# Out:
# webdriver initlized!

# %%
kadai_url = 'https://moodle.s.kyushu-u.ac.jp/mod/assign/view.php?id=159932&action=grading'          # choose which assignment to score
uername_input = '1915476515'      # TA's account
password_input = 'Lch-19950201'     # password
scorer.auto_score(kadai_url, uername_input, password_input)
# Out:
# student:0,name:石川 高志,submit_time:NAN,score:0.00 done!
# student:1,name:松下 晋之介,submit_time:2019年 10月 8日(火曜日) 06:34,score:100.0 done!
# student:2,name:長尾 和,submit_time:2019年 10月 3日(木曜日) 15:27,score:100.0 done!
# student:3,name:増田 修治,submit_time:2019年 10月 8日(火曜日) 23:28,score:100.0 done!
# student:4,name:東嶋 聡美,submit_time:NAN,score:0.00 done!
# student:5,name:杉田 伶央,submit_time:NAN,score:0.00 done!
# student:6,name:相垣 実穂,submit_time:2019年 10月 7日(月曜日) 21:26,score:100.0 done!
# student:7,name:若杉 弥生,submit_time:2019年 10月 8日(火曜日) 22:29,score:100.0 done!
# student:8,name:内田 優人,submit_time:2019年 10月 9日(水曜日) 00:55,score:100.0 done!
# student:9,name:鈴木 孝太郎,submit_time:NAN,score:0.00 done!
# student:10,name:永野 裕太郎,submit_time:2019年 10月 8日(火曜日) 07:36,score:100.0 done!
# student:11,name:荒金 祐一郎,submit_time:NAN,score:0.00 done!
# student:12,name:五斗 優香,submit_time:2019年 10月 9日(水曜日) 08:12,score:100.0 done!
# student:13,name:小林 宙夢,submit_time:NAN,score:0.00 done!
# ...
